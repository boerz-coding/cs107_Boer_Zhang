# %%
import numpy as np
class Markov:
    def __init__(self): # You will need to modify this header line later in Part C
        self.data = self.load_data()
        

    def load_data(self, file_path='./weather.csv'):
        return np.genfromtxt(file_path,delimiter=",")

    def get_prob(self, current_day_weather, next_day_weather): 
        cweather_num=np.nan
        weather_array=np.array(['sunny','cloudy','rainy','snowy','windy','hailing'])
        print(weather_array[0])
        for i in range(0,6):
            if(current_day_weather == weather_array[i]):
                cweather_num=i
        if(cweather_num==np.nan):
            raise 
        print(cweather_num)
          
                
        # Your implementation here
        
mymark=Markov()
mymark.get_prob('sunny','rainy')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/boerzhang/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-21-e3fd803d8916>", line 24, in <module>
#     mymark=Markov()
#   File "<ipython-input-21-e3fd803d8916>", line 4, in __init__
#     self.data = self.load_data()
#   File "<ipython-input-21-e3fd803d8916>", line 8, in load_data
#     return np.genfromtxt(file_path,delimiter=",")
#   File "/Users/boerzhang/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py", line 1749, in genfromtxt
# ...
